# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import rasterio
import geopandas as gpd

# %%
c02_2020 = rasterio.open("../oco2_data/xco2_2020_linear.tif")
plt.imshow(c02_2020.read(1))

# %%
from rasterio.plot import show
show(c02_2020)
# Out:
# <AxesSubplot:>
